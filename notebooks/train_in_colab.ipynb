# %% [markdown]
# # Train RNN to identify russian language
# ## Some configs that you can modify,
# more configs in config.yaml

# %%
OUTPUT_DIR = "./"
TRAIN_PERCENT = 0.6
VALIDATION_PERCENT = 0.2
TEST_PERCENT = 0.2

# %% [markdown]
# ## Cloning repo and extract data

# %%
# %%bash
# # rm -rf ./Russian-Language-Identification
# git clone https://github.com/sergeisoly/Russian-Language-Identification
# cd ./Russian-Language-Identification
# make
# make data

# %% [markdown]
# ## Split dataset to train-validation-test
#  both WILI Dataset and Taiga (Lenta) Dataset

# %%
# %%bash -s "$TRAIN_PERCENT" "$VALIDATION_PERCENT"
# cd ./Russian-Language-Identification
# python3 src/split_datasets.py ./data/lenta/ ./data/ $1 $2

# %% [markdown]
# # Train

# %%
# %cd ./Russian-Language-Identification
# !python3 src/train.py --config ./config.yaml --output_dir {OUTPUT_DIR}
# Out:
# /content/Russian-Language-Identification/Russian-Language-Identification/Russian-Language-Identification
#     output_dir : /content/drive/My Drive/ABBYY_MIPT
#         config : ./config.yaml
#   training_text : ./data/x_train_split.txt
#   training_labels : ./data/y_train_split.txt
#   testing_text : ./data/x_test_split.txt
#   testing_labels : ./data/y_test_split.txt
#   validation_text : ./data/x_valid_split.txt
#   validation_labels : ./data/y_valid_split.txt
#   taiga_train_path : ./data/taiga_train/
#   taiga_valid_path : ./data/taiga_valid/
#   taiga_test_path : ./data/taiga_test/
#     batch_size : 128
#   log_frequency : 100
#      dropout_p : 0.0
#   split_paragraphs : True
#   eval_frequency : 500
#         epochs : 10
#   embedding_dim : 64
#     hidden_dim : 128
#      max_chars : 1000
#   learning_rate : 0.001
#   bidirectional : False
#
# Data loaded.
# Loaded 162869 training samples
# Loaded 54291 validation samples
# Loaded 54292 test samples
#
# ...
